# %%
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

x, y, n = np.random.random(100), np.random.random(100), 100
sum_x, sum_y, sum_x2, sum_xy = np.sum(x), np.sum(y), np.sum(x*x), np.sum(x*y)
m, b = (n*sum_xy - sum_x*sum_y) / (n*sum_x2 - sum_x**2), (sum_x2*sum_y - sum_x*sum_xy) / (n*sum_x2 - sum_x**2)
m_range, b_range = np.linspace(m-0.5, m+0.5, 50), np.linspace(b-0.5, b+0.5, 50)

loss_raw = []
for m_index, m_val in enumerate(m_range):
    loss_raw.append([])
    for b_index, b_val in enumerate(b_range):
        loss_raw[m_index].append(0)
        for i in range(n): loss_raw[m_index][b_index] += (m_val*x[i]+b_val-y[i])**2
loss_range = np.array(loss_raw)

fig = plt.figure()
ax = fig.gca(projection='3d')
graph = ax.plot_surface(m_range, b_range, loss_range, cmap=cm.coolwarm, linewidth=0, antialiased=False)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
